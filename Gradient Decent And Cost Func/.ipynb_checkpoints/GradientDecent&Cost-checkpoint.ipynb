# %%
import numpy as np


def gradient_decent(x,y):
    m_curr = b_curr = 0
    iterations = 100
    n = len(x)
    learning_rate = 0.001
    
    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum ([ val**2 for val in i (y-y_predicted)])
        md = -(2/n) * sum (x * (y-y_predicted))
        bd = -(2/n) * sum (y-y_predicted)
        m_curr = m_curr - learning_rate*md
        b_curr = b_curr - learning_rate * bd
        print("m {}, b {} ,cost {},  iteration {}".format(m_curr,b_curr,cost,i))
        
        

x = np.array([1,2,3,4,5])
y = np.array([5,6,7,8,9])

gradient_decent(x,y)
# Out:
# m 0.046, b 0.014 , iteration 0
# m 0.09090400000000001, b 0.027696 , iteration 1
# m 0.134737936, b 0.041095184 , iteration 2
# m 0.17752713030400002, b 0.054204566015999996 , iteration 3
# m 0.21929630604121603, b 0.067030994102144 , iteration 4
# m 0.2600696013436964, b 0.07958115427769241 , iteration 5
# m 0.29987058318846893, b 0.09186157436107485 , iteration 6
# m 0.3387222609121562, b 0.10387862771322189 , iteration 7
# m 0.3766470994058094, b 0.11563853689232251 , iteration 8
# m 0.4136670319975277, b 0.127147377222103 , iteration 9
# m 0.4498034730302495, b 0.13841108027567364 , iteration 10
# m 0.48507733014192994, b 0.1494354372769408 , iteration 11
# m 0.5195090162551459, b 0.16022610242153534 , iteration 12
# m 0.5531184612830035, b 0.1707885961191614 , iteration 13
# m 0.5859251235580624, b 0.18112830815922504 , iteration 14
# m 0.6179480009908297, b 0.1912505008015582 , iteration 15
# m 0.649205641964222, b 0.20116031179401012 , iteration 16
# m 0.6797161559702452, b 0.21086275731863677 , iteration 17
# m 0.7094972239949879, b 0.22036273486817803 , iteration 18
# m 0.7385661086578892, b 0.22966502605447175 , iteration 19
# m 0.7669396641110888, b 0.23877429935041547 , iteration 20
# m 0.7946343457045424, b 0.24769511276704811 , iteration 21
# m 0.8216662194224402, b 0.25643191646728675 , iteration 22
# m 0.8480509710963429, b 0.2649890553178175 , iteration 23
# m 0.8738039154003164, b 0.27337077138060384 , iteration 24
# m 0.8989400046332259, b 0.2815812063454407 , iteration 25
# m 0.9234738372932223, b 0.2896244039049505 , iteration 26
# m 0.9474196664493417, b 0.29750431207338124 , iteration 27
# m 0.970791407915016, b 0.30522478545053844 , iteration 28
# m 0.9936026482281823, b 0.31278958743214724 , iteration 29
# m 1.0158666524425695, b 0.32020239236791387 , iteration 30
# m 1.0375963717346255, b 0.3274667876685226 , iteration 31
# m 1.0588044508304526, b 0.3345862758627778 , iteration 32
# m 1.079503235257006, b 0.34156427660606953 , iteration 33
# m 1.0997047784217153, b 0.34840412864131537 , iteration 34
# m 1.1194208485245898, b 0.35510909171350247 , iteration 35
# m 1.1386629353067679, b 0.36168234843892794 , iteration 36
# m 1.1574422566393854, b 0.3681270061302095 , iteration 37
# m 1.1757697649565377, b 0.3744460985781128 , iteration 38
# m 1.1936561535360253, b 0.38064258779121735 , iteration 39
# m 1.2111118626314854, b 0.3867193656944188 , iteration 40
# m 1.2281470854594263, b 0.39267925578724105 , iteration 41
# m 1.2447717740445954, b 0.39852501476291 , iteration 42
# m 1.2609956449270368, b 0.40425933408911663 , iteration 43
# m 1.2768281847341072, b 0.40988484155137617 , iteration 44
# m 1.2922786556206485, b 0.4154041027598688 , iteration 45
# m 1.307356100580435, b 0.42081962262062517 , iteration 46
# m 1.3220693486319417, b 0.4261338467719013 , iteration 47
# m 1.3364270198814077, b 0.43134916298656584 , iteration 48
# m 1.3504375304660974, b 0.43646790254130424 , iteration 49
# m 1.3641090973805954, b 0.44149234155342504 , iteration 50
# m 1.3774497431889017, b 0.4464247022860346 , iteration 51
# m 1.3904673006250297, b 0.4512671544223291 , iteration 52
# m 1.403169417084745, b 0.45602181630973426 , iteration 53
# m 1.4155635590110223, b 0.4606907561746063 , iteration 54
# m 1.427657016175732, b 0.46527599330819097 , iteration 55
# m 1.4394569058600168, b 0.4697794992245202 , iteration 56
# m 1.4509701769357493, b 0.4742031987909111 , iteration 57
# m 1.4622036138504173, b 0.4785489713317148 , iteration 58
# m 1.4731638405177179, b 0.4828186517059489 , iteration 59
# m 1.4838573241160924, b 0.48701403135943067 , iteration 60
# m 1.4942903787973818, b 0.49113685935201523 , iteration 61
# m 1.5044691693077272, b 0.49518884336052693 , iteration 62
# m 1.514399714522794, b 0.4991716506579595 , iteration 63
# m 1.524087890899345, b 0.5030869090695068 , iteration 64
# m 1.5335394358451424, b 0.5069362079059717 , iteration 65
# m 1.5427599510091135, b 0.5107210988750889 , iteration 66
# m 1.5517549054936624, b 0.514443096971284 , iteration 67
# m 1.560529638990974, b 0.5181036813443795 , iteration 68
# m 1.5690893648451063, b 0.5217042961477448 , iteration 69
# m 1.5774391730416275, b 0.5252463513663786 , iteration 70
# m 1.5855840331265134, b 0.5287312236253962 , iteration 71
# m 1.5935287970559777, b 0.5321602569793863 , iteration 72
# m 1.6012782019788698, b 0.5355347636830916 , iteration 73
# m 1.608836872953236, b 0.5388560249438522 , iteration 74
# m 1.6162093255986019, b 0.5421252916562451 , iteration 75
# m 1.6233999686854952, b 0.545343785119341 , iteration 76
# m 1.6304131066636982, b 0.5485126977369894 , iteration 77
# m 1.637252942130675, b 0.5516331937015332 , iteration 78
# m 1.6439235782415909, b 0.5547064096613461 , iteration 79
# m 1.6504290210623078, b 0.5577334553725739 , iteration 80
# m 1.6567731818667015, b 0.5607154143354549 , iteration 81
# m 1.6629598793796214, b 0.5636533444155838 , iteration 82
# m 1.6689928419667763, b 0.5665482784504748 , iteration 83
# m 1.6748757097728044, b 0.5694012248417732 , iteration 84
# m 1.680612036808752, b 0.5722131681334529 , iteration 85
# m 1.6862052929901588, b 0.5749850695763334 , iteration 86
# m 1.6916588661269172, b 0.5777178676792398 , iteration 87
# m 1.6969760638660496, b 0.5804124787471199 , iteration 88
# m 1.7021601155885138, b 0.5830697974064294 , iteration 89
# m 1.707214174261128, b 0.5856906971180854 , iteration 90
# m 1.7121413182446747, b 0.5882760306782825 , iteration 91
# m 1.7169445530592222, b 0.5908266307074579 , iteration 92
# m 1.7216268131076746, b 0.5933433101276876 , iteration 93
# m 1.7261909633585397, b 0.5958268626287861 , iteration 94
# m 1.730639800988879, b 0.5982780631233774 , iteration 95
# m 1.7349760569883834, b 0.6006976681911974 , iteration 96
# m 1.7392023977254918, b 0.6030864165128847 , iteration 97
# m 1.7433214264764536, b 0.6054450292935061 , iteration 98
# m 1.7473356849182107, b 0.6077742106760603 , iteration 99
